# %% [markdown]
# # Imports & variables

# %%
# Imports
import time
import requests
from bs4 import BeautifulSoup
from collections import defaultdict
import pandas as pd

# %%
# global variable
continents = ["europa","nordasien","suedostasien","vorderasien","afrika","australien","nordamerika","mittelamerika","suedamerika"]

# %% [markdown]
# ## Funtions

# %%
# function to rework the scrapped data for a easier analyzing
def reworkData(datalist):

    # variable
    # list for unpacking datalist
    listUnpacked = []
    # city to land
    # europe
    cityTOcountry = {
        "Algier": "Algerien",
        "Alicante": "Spanien",
        "Amsterdam": "Niederlande",
        "Ankara": "Türkei",
        "Athen": "Griechenland",
        "Barcelona": "Spanien",
        "Bari": "Italien",
        "Belgrad": "Serbien",
        "Berlin": "Deutschland",
        "Bordeaux": "Frankreich",
        "Bratislava": "Slowakei",
        "Brest": "Frankreich",
        "Brocken": "Deutschland",
        "Brüssel": "Belgien",
        "Budapest": "Ungarn",
        "Bukarest": "Rumänien",
        "Cork": "Irland",
        "Dresden": "Deutschland",
        "Dublin": "Irland",
        "Dubrovnik": "Kroatien",
        "Faro": "Portugal",
        "Feldberg/Schw.": "Deutschland",
        "Frankfurt/Flh.": "Deutschland",
        "Genf": "Schweiz",
        "Genua": "Italien",
        "Graz": "Österreich",
        "Hamburg": "Deutschland",
        "Helgoland": "Deutschland",
        "Helsinki": "Finnland",
        "Heraklion": "Griechenland",
        "Ibiza": "Spanien",
        "Innsbruck": "Österreich",
        "Istanbul": "Türkei",
        "Izmir": "Türkei",
        "Kairo": "Ägypten",
        "Kiew": "Ukraine",
        "Köln": "Deutschland",
        "Kopenhagen": "Dänemark",
        "La Coruna": "Spanien",
        "Larnaka": "Zypern",
        "Las Palmas": "Spanien",
        "Lerwick": "Vereinigtes Königreich",
        "Lissabon": "Portugal",
        "Ljubljana": "Slowenien",
        "London": "Vereinigtes Königreich",
        "Luxemburg": "Luxemburg",
        "Madrid": "Spanien",
        "Mailand": "Italien",
        "Malaga": "Spanien",
        "Malta": "Malta",
        "Messina": "Italien",
        "Minsk": "Weißrussland",
        "Montpellier": "Frankreich",
        "Moskau": "Russland",
        "München": "Deutschland",
        "Nizza": "Frankreich",
        "Odense": "Dänemark",
        "Odessa": "Ukraine",
        "Oslo": "Norwegen",
        "Palma[de Mallorca]": "Spanien",
        "Paris": "Frankreich",
        "Porto": "Portugal",
        "Prag": "Tschechien",
        "Rabat": "Marokko",
        "Rennes": "Frankreich",
        "Reykjavik": "Island",
        "Rhodos": "Griechenland",
        "Riga": "Lettland",
        "Rom": "Italien",
        "Salzburg": "Österreich",
        "Santander": "Spanien",
        "Sarajevo": "Bosnien und Herzegowina",
        "Sofia": "Bulgarien",
        "Split": "Kroatien",
        "Stavanger": "Norwegen",
        "Stockholm": "Schweden",
        "St. Petersburg": "Russland",
        "Strassburg": "Frankreich",
        "Stuttgart": "Deutschland",
        "Tallinn": "Estland",
        "Thessaloniki": "Griechenland",
        "Tromsoe": "Norwegen",
        "Tunis": "Tunesien",
        "Vaduz": "Liechtenstein",
        "Varna": "Bulgarien",
        "Vigo": "Spanien",
        "Vilnius": "Litauen",
        "Wien": "Österreich",
        "Zugspitze": "Deutschland",
        "Zürich": "Schweiz"
    }
    # north-asia & GUS
    cityTOcountry.update({
        "Alma-Ata": "Kasachstan",
        "Archangelsk": "Russland",
        "Dnjpropetrovsk": "Ukraine",
        "Dudinka": "Russland",
        "Dushanbe": "Tadschikistan",
        "Ekaterinburg": "Russland",
        "Irkutsk": "Russland",
        "Jakutsk": "Russland",
        "Kaliningrad": "Russland",
        "Kaunas": "Litauen",
        "Kljuchi": "Russland",
        "Murmansk": "Russland",
        "Novosibirsk": "Russland",
        "Omsk": "Russland",
        "Ostrov Dikson": "Russland",
        "Samarkand": "Usbekistan",
        "Sotschi": "Russland",
        "Tallin": "Estland",  # correct name would be "Tallinn" but website wrote it so
        "Taschkent": "Usbekistan",
        "Tbilisi": "Georgien",
        "Termez": "Usbekistan",
        "Tiksi": "Russland",
        "Wladiwostok": "Russland",
        "Wolgograd": "Russland"
    })
    # southeast-asia
    cityTOcountry.update({
        "Bangkok": "Thailand",
        "Brunei": "Brunei",
        "Cocos Island": "Australien",
        "Hanoi": "Vietnam",
        "Hongkong": "China",
        "Jakarta": "Indonesien",
        "Kuala Lumpur": "Malaysia",
        "Macao": "China",
        "Mandalay": "Myanmar",
        "Manila": "Philippinen",
        "Osaka": "Japan",
        "Peking": "China",
        "Penang": "Malaysia",
        "Saigon": "Vietnam",
        "Seoul": "Südkorea",
        "Shanghai": "China",
        "Singapur": "Singapur",
        "Tokyo": "Japan"
    })
    # near east
    cityTOcountry.update({
        "Abu Dhabi": "Vereinigte Arabische Emirate",
        "Adana": "Türkei",
        "Aden": "Jemen",
        "Al Ain": "Vereinigte Arabische Emirate",
        "Amman": "Jordanien",
        "Antalya": "Türkei",
        "Bahrain": "Bahrain",
        "Bombay": "Indien",  # today Mumbai
        "Bursa": "Türkei",
        "Calcutta": "Indien",  # today Kolkata
        "Damascus": "Syrien",
        "Doha": "Katar",
        "Dubai": "Vereinigte Arabische Emirate",
        "Esfahan": "Iran",
        "Haifa": "Israel",
        "Islamabad": "Pakistan",
        "Isparta": "Türkei",
        "Jeddah": "Saudi-Arabien",
        "Kathmandu": "Nepal",
        "Kermanshah": "Iran",
        "Kuwait": "Kuwait",
        "Madras": "Indien",  # today Chennai
        "Mekka": "Saudi-Arabien",
        "Mersa Matruh": "Ägypten",
        "Neu Delhi": "Indien",
        "Riad": "Saudi-Arabien",
        "Seeb": "Oman",
        "Shiraz": "Iran",
        "Sivas": "Türkei",
        "Tel Aviv": "Israel",
        "Trabzon": "Türkei"
    })
    # australia
    cityTOcountry.update({
        "Adelaide": "Australien",
        "Albany": "Australien",
        "Alice Springs": "Australien",
        "Auckland": "Neuseeland",
        "Brisbane": "Australien",
        "Broken Hill": "Australien",
        "Broome": "Australien",
        "Cairns": "Australien",
        "Canberra": "Australien",
        "Carnarvon": "Australien",
        "Christchurch": "Neuseeland",
        "Darwin": "Australien",
        "Hobart": "Australien",
        "Hokitika": "Neuseeland",
        "Invercargill": "Neuseeland",
        "Lord Howe Island": "Australien",
        "Macquarie Island": "Australien",
        "Port Hedland": "Australien",
        "Queenstown": "Neuseeland",
        "Rarotonga": "Cookinseln",  # standalone, but in free association with New Zealand
        "Sydney": "Australien",
        "Taupo": "Neuseeland",
        "Tindal": "Australien",
        "Townsville": "Australien",
        "Wellington": "Neuseeland"
    })
    # africa
    cityTOcountry.update({
        "Accra": "Ghana",
        "Agadir": "Marokko",
        "Alexandria": "Ägypten",
        "Antananarivo": "Madagaskar",
        "Assuan": "Ägypten",
        "Casablanca": "Marokko",
        "Dakar": "Senegal",
        "DarEsSalaam": "Tansania",
        "Djerba": "Tunesien",
        "Durban": "Südafrika",
        "Hurghada": "Ägypten",
        "Johannesburg": "Südafrika",
        "Kairo": "Ägypten",
        "Kapstadt": "Südafrika",
        "Khartum": "Sudan",
        "Kigali": "Ruanda",
        "Kilimanjaro": "Tansania",
        "Kinshasa": "Demokratische Republik Kongo",
        "Lagos": "Nigeria",
        "Lanzarote": "Spanien",  # Canary Islands
        "LasPalmas": "Spanien",  # Canary Islands
        "Livingstone": "Sambia",
        "Lusaka": "Sambia",
        "Luxor": "Ägypten",
        "Marrakech": "Marokko",
        "Mombasa": "Kenia",
        "Nairobi": "Kenia",
        "Ouagadougou": "Burkina Faso",
        "Rabat": "Marokko",
        "Seychelles": "Seychellen",
        "Tanger": "Marokko",
        "Tripolis": "Libyen",
        "Tunis": "Tunesien",
        "Victoria Falls": "Simbabwe",
        "Windhuk": "Namibia"
    })
    # north-america
    cityTOcountry.update({
        "Albuquerque": "USA",
        "Anchorage": "USA",
        "Atlanta GA.": "USA",
        "Atlantic City": "USA",
        "Austin": "USA",
        "Baltimore": "USA",
        "Bismarck": "USA",
        "Boston": "USA",
        "Brownsville": "USA",
        "Buffalo": "USA",
        "Calgary": "Kanada",
        "Cheyenne": "USA",
        "Chicago": "USA",
        "Churchill": "Kanada",
        "Cincinnati": "USA",
        "Cleveland": "USA",
        "Dallas": "USA",
        "Dawson City": "Kanada",
        "Denver": "USA",
        "Detroit": "USA",
        "Dodge City": "USA",
        "Edmonton": "Kanada",
        "El Paso": "USA",
        "Eureka": "USA",
        "Fairbanks": "USA",
        "Fargo": "USA",
        "Fresno": "USA",
        "Goose Bay NF.": "Kanada",
        "Halifax": "Kanada",
        "Houston": "USA",
        "Indianapolis": "USA",
        "Jacksonville": "USA",
        "Kansas City": "USA",
        "Key West": "USA",
        "Las Vegas": "USA",
        "Los Angeles": "USA",
        "Louisville": "USA",
        "Memphis": "USA",
        "Miami": "USA",
        "Milwaukee": "USA",
        "Minneapolis": "USA",
        "Montreal": "Kanada",
        "Nashville": "USA",
        "New Orleans": "USA",
        "New York": "USA",
        "Oklahoma City": "USA",
        "Orlando/Jetport": "USA",
        "Ottawa": "Kanada",
        "Philadelphia": "USA",
        "Phoenix": "USA",
        "Pittsburgh": "USA",
        "Portland": "USA",
        "Quebec": "Kanada",
        "Reno": "USA",
        "Resolute": "Kanada",
        "Salt Lake City": "USA",
        "San Antonio": "USA",
        "San Diego": "USA",
        "San Francisco": "USA",
        "Schefferville": "Kanada",
        "Seattle": "USA",
        "St. Louis": "USA",
        "Sydney": "Kanada",  # not Australia! Nova Scotia, Kanada
        "Syracuse": "USA",
        "Tallahassee": "USA",
        "Tampa": "USA",
        "Thunder Bay": "Kanada",
        "Toronto": "Kanada",
        "Tucson": "USA",
        "Vancouver": "Kanada",
        "Washington": "USA",
        "Wichita Falls": "USA",
        "Winnipeg": "Kanada"
    })
    # middle-america & Caribic
    cityTOcountry.update({
        "Acapulco": "Mexiko",
        "Aruba": "Niederlande",  # part of the netherlands (autonomous)
        "Belize": "Belize",
        "Bermuda": "Vereinigtes Königreich",
        "Bonaire": "Niederlande",  # special community
        "Castries": "St. Lucia",
        "Chihuahua": "Mexiko",
        "Curacao": "Niederlande",  # autonomous country
        "Grantley Adams": "Barbados",
        "Grenada": "Grenada",
        "Guadalajara": "Mexiko",
        "Guadeloupe": "Frankreich",
        "Havanna": "Kuba",
        "Kingston": "Jamaika",
        "La Paz": "Mexiko",
        "Le Lamentin": "Martinique (Frankreich)",
        "Liberia": "Costa Rica",
        "Manzanillo": "Mexiko",
        "Merida": "Mexiko",
        "Mexico": "Mexiko",
        "Montego Bay": "Jamaika",
        "Monterrey": "Mexiko",
        "Nassau": "Bahamas",
        "Puerto Limon": "Costa Rica",
        "Puerto Plata": "Dominikanische Republik",
        "Punta Cana": "Dominikanische Republik",
        "Puntarenas": "Costa Rica",
        "San Jose": "Costa Rica",
        "San Juan": "Puerto Rico (USA)",
        "Santiago": "Dominikanische Republik",
        "Santo Domingo": "Dominikanische Republik",
        "St. Luccia": "St. Lucia",
        "St. Maarten": "Niederlande",  # autonomous, southpart of the island
        "Tegucigalpa": "Honduras",
        "Tampico": "Mexiko",
        "Tobago": "Trinidad und Tobago",
        "Trinidad": "Trinidad und Tobago",
        "Veracruz": "Mexiko"
    })
    # south-america
    cityTOcountry.update({
        "Antofagasta": "Chile",
        "Ascuncion": "Paraguay",
        "Belem": "Brasilien",
        "Boa Vista": "Brasilien",
        "Bogota": "Kolumbien",
        "Brasilia": "Brasilien",
        "Buenos Aires": "Argentinien",
        "Caracas": "Venezuela",
        "Cartagena": "Kolumbien",
        "Catamarca": "Argentinien",
        "Cayenne": "Französisch-Guayana",  # overseas territory of France
        "Cordoba": "Argentinien",
        "Cuiaba": "Brasilien",
        "Esquel": "Argentinien",
        "Falklands": "Vereinigtes Königreich",  # british overseas territory
        "Georgetown": "Guyana",
        "Iquitos": "Peru",
        "Juliaca": "Peru",
        "Kap Hoorn": "Chile",  # Southern tip Southamerica
        "La Paz": "Bolivien",
        "Lima": "Peru",
        "Maracaibo": "Venezuela",
        "Mendoza": "Argentinien",
        "Merida": "Venezuela",
        "Montevideo": "Uruguay",
        "Osterinseln": "Chile",
        "Piura": "Peru",
        "Porlamar": "Venezuela",
        "Porto Alegre": "Brasilien",
        "Puerto Montt": "Chile",
        "Rio de Janeiro": "Brasilien",
        "Rio Negro": "Argentinien",  # province
        "Sao Paulo": "Brasilien",
        "Tobago": "Trinidad und Tobago",
        "Ushuaia": "Argentinien"
    })

    # group by value of country
    temperatureBYcountry = defaultdict(list)

    # go through every data entry
    for continent in datalist:
        for country in continent:
            if country:
                countryname = country[0]
                try:
                    temp = float(country[3])
                except (ValueError, TypeError):
                    temp = 0.0
                print(f"{countryname},{temp}")

    # ## iteration through every entry
    # for entry in cleaned:
    #     if not isinstance(entry[0], str):
    #         print("⚠️ Kein gültiger Städtename:", entry[0])
    #         continue
    #     city = entry[0]
    #     try:
    #         temp = float(entry[3])
    #     except (ValueError, TypeError):
    #         temp = 0.0
    #     # city -> land
    #     land = cityTOcountry.get(city)
    #     if land:
    #         temperatureBYcountry[land].append(temp)
    #     print(f"{city}: {temp}°C")

    # # calculate average temperature of the countries (only possible, if there are more than one)
    # result = []
    # for land, temps in temperatureBYcountry.items():
    #     durchschnitt = sum(temps) / len(temps)
    #     result.append([land, round(durchschnitt, 2)])

    #return result

# %%
# function to scrap the data from the website "www.dwd.de" -> "deutscher Wetterdienst"
def scrapData():
    # local variable
    scrappedData = []

    # get data from every continent
    for continent in continents:
        time.sleep(2)
        url = f"https://www.dwd.de/DE/wetter/wetter_weltweit/{continent}/wetterwerte/_node.html"
        resp = requests.get(url)
        print(url)
        
        # check if the website is responding
        if resp.status_code != 200:
                print(f"[!] Seite nicht erreichbar (Status {resp.status_code}). Beende Scrapping.")
        else:
            datacontinent = []
            # get the htmlstructure
            soup = BeautifulSoup(resp.text, 'html.parser')
            # get the tablestructure (if exists, threfore also a check)
            table = soup.find('table')
            
            if not table:
                print(f"[!] Keine Tabelle auf Seite. Beende Scrapping.")
            else:
                # get all tr tags and then all td tags, further save every data row as a list 
                rows = table.find_all('tr')
                for tr in rows:
                    tds = tr.find_all('td')
                    datarow = []
                    for td in tds:
                        datarow.append(td.get_text(strip=True))
                    datacontinent.append(datarow)
        
                # save the continent data into the scrapped data list
                scrappedData.append(datacontinent)

    # rework scrapped data
    return reworkData(scrappedData)

# %% [markdown]
# # Execution

# %%
data = scrapData()
print(data)
# Out:
# https://www.dwd.de/DE/wetter/wetter_weltweit/europa/wetterwerte/_node.html
# https://www.dwd.de/DE/wetter/wetter_weltweit/nordasien/wetterwerte/_node.html
# https://www.dwd.de/DE/wetter/wetter_weltweit/suedostasien/wetterwerte/_node.html
# [!] Seite nicht erreichbar (Status 403). Beende Scrapping.
# https://www.dwd.de/DE/wetter/wetter_weltweit/vorderasien/wetterwerte/_node.html
# [!] Seite nicht erreichbar (Status 403). Beende Scrapping.
# https://www.dwd.de/DE/wetter/wetter_weltweit/afrika/wetterwerte/_node.html
# https://www.dwd.de/DE/wetter/wetter_weltweit/australien/wetterwerte/_node.html
# https://www.dwd.de/DE/wetter/wetter_weltweit/nordamerika/wetterwerte/_node.html
# https://www.dwd.de/DE/wetter/wetter_weltweit/mittelamerika/wetterwerte/_node.html
# https://www.dwd.de/DE/wetter/wetter_weltweit/suedamerika/wetterwerte/_node.html
# countryname: Algier, temp.: 26.6
# countryname: Alicante, temp.: 28.8
# countryname: Amsterdam, temp.: 19.1
# countryname: Ankara, temp.: 21.9
# ...
