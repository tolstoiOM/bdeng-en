# %% [markdown]
# # Wetterdaten, Luftqualität und Lebenserwartung

# %% [markdown]
# ### Group Members
# - Lukas Prager
# - Ivan Blazevic
# - Chamberg Zelimchanow
#
# ### Link to Github Repository
# https://github.com/tolstoiOM/bdeng-en

# %% [markdown]
# ![image.png](attachment:03952210-d184-43ab-927b-255d1986bd60.png)

# %% [markdown]
# ![image.png](attachment:25dda93d-275a-4955-b539-77761bf8095e.png)

# %% [markdown]
# ![image.png](attachment:e0de6d16-e272-4b9b-921e-3db2869629af.png)

# %% [markdown]
# ![image.png](attachment:03753fc8-cda3-49db-9f42-e01b859f2f54.png)

# %% [markdown]
# ![image.png](attachment:c944726f-01f9-4d4d-a226-caef091e0aad.png)

# %% [markdown]
# ![image.png](attachment:a2133149-6ba8-4d1b-947b-ab762372650b.png)

# %% [markdown]
# ![image.png](attachment:042eb5dd-8bf4-4ccf-96f5-b5a54a578bcd.png)

# %% [markdown]
# ![image.png](attachment:9d4e6e03-e724-40c3-b197-dbb7364d77d0.png)

# %% [markdown]
# ![image.png](attachment:713a7c5a-1b8c-47a5-8707-1b4b48dfea3f.png)
